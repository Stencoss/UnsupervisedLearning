# %% [markdown]
# # Unsupervised Project
# ## Cryptoboys

# %%
# import all my needs
import pandas as pd

# %%
# Load data into df

df = pd.read_csv('crypto_data.csv')
df.columns
# Out:
# Index(['Unnamed: 0', 'CoinName', 'Algorithm', 'IsTrading', 'ProofType',
#        'TotalCoinsMined', 'TotalCoinSupply'],
#       dtype='object')

# %%
# Discard all cryptocurriences not being traded 
# Check if isTrading is False - if so then delete row
# Drop NaN and it needs to be mined
df_clean = df[df['IsTrading']].dropna()
df_clean = df_clean[df_clean['TotalCoinsMined'] > 0]
df_clean = df_clean.drop('CoinName', axis=1)
df_clean
# Out:
#      Unnamed: 0    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0            42       Scrypt       True   PoW/PoS     4.199995e+01
# 2           404       Scrypt       True   PoW/PoS     1.055185e+09
# 5          1337          X13       True   PoW/PoS     2.927942e+10
# 7           BTC      SHA-256       True       PoW     1.792718e+07
# 8           ETH       Ethash       True       PoW     1.076842e+08
# ...         ...          ...        ...       ...              ...
# 1238       ZEPH      SHA-256       True      DPoS     2.000000e+09
# 1242        GAP       Scrypt       True   PoW/PoS     1.493105e+07
# 1245        BDX  CryptoNight       True       PoW     9.802226e+08
# 1246        ZEN     Equihash       True       PoW     7.296538e+06
# 1247        XBC       Scrypt       True       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 2          532000000
# 5       314159265359
# 7           21000000
# 8                  0
# ...              ...
# 1238      2000000000
# 1242       250000000
# 1245      1400222610
# 1246        21000000
# 1247         1000000
#
# [532 rows x 6 columns]

# %%
# Create get_summies

pd.get_dummies(df_clean)
# Out:
#       IsTrading  TotalCoinsMined  Unnamed: 0_1337  Unnamed: 0_1CR  \
# 0          True     4.199995e+01                0               0
# 2          True     1.055185e+09                0               0
# 5          True     2.927942e+10                1               0
# 7          True     1.792718e+07                0               0
# 8          True     1.076842e+08                0               0
# ...         ...              ...              ...             ...
# 1238       True     2.000000e+09                0               0
# 1242       True     1.493105e+07                0               0
# 1245       True     9.802226e+08                0               0
# 1246       True     7.296538e+06                0               0
# 1247       True     1.283270e+05                0               0
#
#       Unnamed: 0_404  Unnamed: 0_42  Unnamed: 0_8BIT  Unnamed: 0_AAC  \
# 0                  0              1                0               0
# 2                  1              0                0               0
# 5                  0              0                0               0
# 7                  0              0                0               0
# 8                  0              0                0               0
# ...              ...            ...              ...             ...
# 1238               0              0                0               0
# 1242               0              0                0               0
# 1245               0              0                0               0
# 1246               0              0                0               0
# 1247               0              0                0               0
#
#       Unnamed: 0_ABJ  Unnamed: 0_ABS  ...  TotalCoinSupply_91388946  \
# 0                  0               0  ...                         0
# 2                  0               0  ...                         0
# 5                  0               0  ...                         0
# 7                  0               0  ...                         0
# 8                  0               0  ...                         0
# ...              ...             ...  ...                       ...
# 1238               0               0  ...                         0
# 1242               0               0  ...                         0
# 1245               0               0  ...                         0
# 1246               0               0  ...                         0
# 1247               0               0  ...                         0
#
#       TotalCoinSupply_92000000000  TotalCoinSupply_9354000  \
# 0                               0                        0
# 2                               0                        0
# 5                               0                        0
# 7                               0                        0
# 8                               0                        0
# ...                           ...                      ...
# 1238                            0                        0
# 1242                            0                        0
# 1245                            0                        0
# 1246                            0                        0
# 1247                            0                        0
#
#       TotalCoinSupply_9507271  TotalCoinSupply_9736000  \
# 0                           0                        0
# 2                           0                        0
# 5                           0                        0
# 7                           0                        0
# 8                           0                        0
# ...                       ...                      ...
# 1238                        0                        0
# 1242                        0                        0
# 1245                        0                        0
# 1246                        0                        0
# 1247                        0                        0
#
#       TotalCoinSupply_98000000  TotalCoinSupply_98100000000  \
# 0                            0                            0
# 2                            0                            0
# 5                            0                            0
# 7                            0                            0
# 8                            0                            0
# ...                        ...                          ...
# 1238                         0                            0
# 1242                         0                            0
# 1245                         0                            0
# 1246                         0                            0
# 1247                         0                            0
#
#       TotalCoinSupply_990000000000  TotalCoinSupply_999481516  \
# 0                                0                          0
# 2                                0                          0
# 5                                0                          0
# 7                                0                          0
# 8                                0                          0
# ...                            ...                        ...
# 1238                             0                          0
# 1242                             0                          0
# 1245                             0                          0
# 1246                             0                          0
# 1247                             0                          0
#
#       TotalCoinSupply_9999999
# 0                           0
# 2                           0
# 5                           0
# 7                           0
# 8                           0
# ...                       ...
# 1238                        0
# 1242                        0
# 1245                        0
# 1246                        0
# 1247                        0
#
# [532 rows x 910 columns]
